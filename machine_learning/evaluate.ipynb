# %%
import time
import sys
import os

current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

from bot.ml_bot import MLBot
from bot.random_bot import RandomBot
from state.board import Board, Color

# %%
def play_match(white_bot, black_bot, max_moves=1000):
    """
    Chạy 1 ván cờ.
    Trả về: 1 (Trắng thắng), -1 (Đen thắng), 0 (Hòa)
    """
    board = Board()
    moves = 0
    
    while moves < max_moves:
        # 1. Kiểm tra kết thúc game trước khi đi
        if not board._has_legal_moves_for(board.turn):
            if board.is_in_check(board.turn):
                # Bị chiếu mà không đi được -> Thua
                return -1 if board.turn == Color.WHITE else 1
            else:
                # Không đi được nhưng không bị chiếu -> Hòa (Stalemate)
                return 0

        # 2. Chọn nước đi
        try:
            if board.turn == Color.WHITE:
                next_state = white_bot.choose_move(board)
            else:
                next_state = black_bot.choose_move(board)
        except Exception as e:
            print(f"Lỗi bot: {e}")
            return 0 # Coi như hòa nếu lỗi

        # 3. Xử lý kết quả trả về
        if next_state is None:
            # Bot đầu hàng hoặc không tìm thấy nước đi (dù check bên trên đã pass)
            if board.is_in_check(board.turn):
                return -1 if board.turn == Color.WHITE else 1
            return 0

        # 4. Cập nhật bàn cờ
        board = next_state.board
        moves += 1

    # Hết lượt đi mà chưa ai thắng -> Hòa (Draw by Move Limit)
    return 0

# %%
def run_tournament(num_games=10):
    print(f"{'='*40}")
    print(f"BẮT ĐẦU: {num_games} TRẬN")
    print(f"TRẮNG: MLBot | ĐEN: RandomBot")
    print(f"{'='*40}")

    # Load bot (Chỉ load 1 lần để tiết kiệm thời gian)
    white_bot = MLBot()
    black_bot = RandomBot()

    stats = {"ML_Win": 0, "Random_Win": 0, "Draw": 0}

    for i in range(1, num_games + 1):
        print(f"Đang chạy ván {i}/{num_games}...", end=" ", flush=True)
        
        start_time = time.time()
        result = play_match(white_bot, black_bot)
        end_time = time.time()
        
        duration = end_time - start_time
        
        if result == 1:
            print(f"[ML Thắng] ({duration:.2f}s)")
            stats["ML_Win"] += 1
        elif result == -1:
            print(f"[Random Thắng] ({duration:.2f}s)")
            stats["Random_Win"] += 1
        else:
            print(f"[Hòa] ({duration:.2f}s)")
            stats["Draw"] += 1

    print(f"\n{'='*40}")
    print(f"KẾT QUẢ TỔNG HỢP SAU {num_games} VÁN")
    print(f"{'='*40}")
    print(f"--- ML Bot thắng    : {stats['ML_Win']} ({stats['ML_Win']/num_games*100:.1f}%)")
    print(f"--- Random Bot thắng: {stats['Random_Win']} ({stats['Random_Win']/num_games*100:.1f}%)")
    print(f"--- Hòa             : {stats['Draw']} ({stats['Draw']/num_games*100:.1f}%)")
    print(f"{'='*40}")

# %%
run_tournament(num_games=100)
# Out:
# ========================================
# BẮT ĐẦU: 100 TRẬN
# TRẮNG: MLBot | ĐEN: RandomBot
# ========================================
# MLBot: Loaded model successfully.
# Đang chạy ván 1/100... [Hòa] (23.07s)
# Đang chạy ván 2/100... [ML Thắng] (9.61s)
# Đang chạy ván 3/100... [ML Thắng] (1.78s)
# Đang chạy ván 4/100... [ML Thắng] (20.83s)
# Đang chạy ván 5/100... [Hòa] (15.17s)
# Đang chạy ván 6/100... [ML Thắng] (1.34s)
# Đang chạy ván 7/100... [Hòa] (11.34s)
# Đang chạy ván 8/100... [ML Thắng] (2.45s)
# Đang chạy ván 9/100... [Hòa] (14.68s)
# Đang chạy ván 10/100... [ML Thắng] (3.71s)
# Đang chạy ván 11/100... [ML Thắng] (2.35s)
# Đang chạy ván 12/100... [ML Thắng] (1.64s)
# Đang chạy ván 13/100... [ML Thắng] (3.37s)
# Đang chạy ván 14/100... [Hòa] (18.30s)
# Đang chạy ván 15/100... [ML Thắng] (2.94s)
# Đang chạy ván 16/100... [Hòa] (12.76s)
# Đang chạy ván 17/100... [ML Thắng] (0.38s)
# Đang chạy ván 18/100... [Hòa] (9.06s)
# Đang chạy ván 19/100... [Hòa] (10.34s)
# Đang chạy ván 20/100... [ML Thắng] (4.14s)
# Đang chạy ván 21/100... [ML Thắng] (3.92s)
# Đang chạy ván 22/100... [Hòa] (10.35s)
# Đang chạy ván 23/100... [ML Thắng] (4.02s)
# Đang chạy ván 24/100... [ML Thắng] (4.62s)
# Đang chạy ván 25/100... [ML Thắng] (4.30s)
# Đang chạy ván 26/100... [ML Thắng] (4.10s)
# Đang chạy ván 27/100... [ML Thắng] (10.15s)
# Đang chạy ván 28/100... [Hòa] (10.85s)
# Đang chạy ván 29/100... [Hòa] (15.60s)
# Đang chạy ván 30/100... [ML Thắng] (2.87s)
# Đang chạy ván 31/100... [ML Thắng] (3.48s)
# Đang chạy ván 32/100... [Hòa] (20.18s)
# Đang chạy ván 33/100... [ML Thắng] (2.14s)
# Đang chạy ván 34/100... [ML Thắng] (3.71s)
# Đang chạy ván 35/100... [Hòa] (17.32s)
# Đang chạy ván 36/100... [Hòa] (16.25s)
# Đang chạy ván 37/100... [Hòa] (17.01s)
# Đang chạy ván 38/100... [ML Thắng] (1.17s)
# Đang chạy ván 39/100... [ML Thắng] (3.27s)
# Đang chạy ván 40/100... [Hòa] (15.99s)
# Đang chạy ván 41/100... [Hòa] (15.43s)
# Đang chạy ván 42/100... [ML Thắng] (1.60s)
# Đang chạy ván 43/100... [Hòa] (12.98s)
# Đang chạy ván 44/100... [Hòa] (12.85s)
# Đang chạy ván 45/100... [ML Thắng] (1.75s)
# Đang chạy ván 46/100... [ML Thắng] (3.82s)
# Đang chạy ván 47/100... [Hòa] (7.50s)
# Đang chạy ván 48/100... [ML Thắng] (3.07s)
# Đang chạy ván 49/100... [Hòa] (12.74s)
# Đang chạy ván 50/100... [ML Thắng] (2.80s)
# Đang chạy ván 51/100... [ML Thắng] (3.12s)
# Đang chạy ván 52/100... [ML Thắng] (3.95s)
# Đang chạy ván 53/100... [ML Thắng] (4.57s)
# Đang chạy ván 54/100... [ML Thắng] (2.76s)
# Đang chạy ván 55/100... [Hòa] (6.12s)
# Đang chạy ván 56/100... [ML Thắng] (1.51s)
# Đang chạy ván 57/100... [Hòa] (11.74s)
# Đang chạy ván 58/100... [Hòa] (6.32s)
# Đang chạy ván 59/100... [ML Thắng] (4.80s)
# Đang chạy ván 60/100... [Hòa] (10.62s)
# Đang chạy ván 61/100... [ML Thắng] (3.42s)
# Đang chạy ván 62/100... [ML Thắng] (1.58s)
# Đang chạy ván 63/100... [Hòa] (8.35s)
# Đang chạy ván 64/100... [ML Thắng] (2.09s)
# Đang chạy ván 65/100... [ML Thắng] (4.06s)
# Đang chạy ván 66/100... [Hòa] (15.69s)
# Đang chạy ván 67/100... [ML Thắng] (1.41s)
# Đang chạy ván 68/100... [ML Thắng] (0.98s)
# Đang chạy ván 69/100... [ML Thắng] (2.60s)
# Đang chạy ván 70/100... [ML Thắng] (2.78s)
# Đang chạy ván 71/100... [Hòa] (10.79s)
# Đang chạy ván 72/100... [ML Thắng] (1.58s)
# Đang chạy ván 73/100... [ML Thắng] (1.54s)
# Đang chạy ván 74/100... [ML Thắng] (2.18s)
# Đang chạy ván 75/100... [ML Thắng] (2.69s)
# Đang chạy ván 76/100... [ML Thắng] (4.88s)
# Đang chạy ván 77/100... [ML Thắng] (4.92s)
# Đang chạy ván 78/100... [Hòa] (15.19s)
# Đang chạy ván 79/100... [ML Thắng] (3.00s)
# Đang chạy ván 80/100... [ML Thắng] (4.94s)
# Đang chạy ván 81/100... [ML Thắng] (5.69s)
# Đang chạy ván 82/100... [ML Thắng] (2.61s)
# Đang chạy ván 83/100... [ML Thắng] (1.62s)
# Đang chạy ván 84/100... [Hòa] (15.60s)
# Đang chạy ván 85/100... [Hòa] (10.18s)
# Đang chạy ván 86/100... [ML Thắng] (5.41s)
# Đang chạy ván 87/100... [ML Thắng] (2.66s)
# Đang chạy ván 88/100... [Hòa] (13.54s)
# Đang chạy ván 89/100... [ML Thắng] (4.34s)
# Đang chạy ván 90/100... [ML Thắng] (4.95s)
# Đang chạy ván 91/100... [ML Thắng] (2.14s)
# Đang chạy ván 92/100... [ML Thắng] (2.28s)
# Đang chạy ván 93/100... [ML Thắng] (2.45s)
# Đang chạy ván 94/100... [ML Thắng] (2.25s)
# Đang chạy ván 95/100... [Hòa] (15.01s)
# Đang chạy ván 96/100... [ML Thắng] (4.02s)
# Đang chạy ván 97/100... [ML Thắng] (3.27s)
# Đang chạy ván 98/100... [ML Thắng] (4.15s)
# Đang chạy ván 99/100... [Hòa] (24.51s)
# Đang chạy ván 100/100... [ML Thắng] (1.64s)
#
# ========================================
# KẾT QUẢ TỔNG HỢP SAU 100 VÁN
# ========================================
# --- ML Bot thắng    : 66 (66.0%)
# --- Random Bot thắng: 0 (0.0%)
# --- Hòa             : 34 (34.0%)
# ========================================
